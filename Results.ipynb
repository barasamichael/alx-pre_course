# %% [markdown]
# # <span style = "color:red;">INTERMEDIATE CERTIFICATE IN DATA SCIENCE - FINAL PROJECT</span>
# # <span style = "color:#1A237E;">Problem Statement</span>
# To explore the relationship between poverty indicators and credit access among Kenyan households.
# ## <span style = "color:green;">Explanation</span>
# Poverty is a major issue in Kenya, with a large portion of the population living below the poverty line.
# The government has put in place policies and programs to alleviate poverty, but their effectiveness is
# not well known. The study aims to investigate the factors
# that affect credit access among Kenyan households and assess how credit access affects poverty levels
# in the country.

# %% [markdown]
# # <span style = "color:#1A237E;">Summary of Hypotheses</span>
# ## <span style = "color:green;">Hypothesis One</span>
# ### <span style = "color:brown;">Null Hypothesis</span>
# Households in counties with lower headcount rates are less likely to access credit.
# ### <span style = "color:brown;">Alternative Hypothesis</span>
# Households in counties with higher headcount rates are less likely to access credit.
# ### <span style = "color:brown;">Relevance</span>
# In Kenya, poverty is more prevalent in some counties compared to others.
# Therefore, it is hypothesized that households in poorer counties will have less access to credit,
# which may worsen their poverty status.
# ## <span style = "color:green;">Hypothesis Two</span>
# ### <span style = "color:brown;">Null Hypothesis</span>
# Households in counties with higher poverty gaps are more likely to access credit.
# ### <span style = "color:brown;">Alternative Hypothesis</span>
# Households in counties with higher poverty gaps are less likely to access credit.
# ### <span style = "color:brown;">Relevance</span>
# Poverty gaps measure the depth of poverty, indicating how far the poor are from the poverty line.
# If households are far from the poverty line, they may face more difficulties accessing credit,
# thereby exacerbating their poverty situation.
# ## <span style = "color:green;">Hypothesis Three</span>
# ### <span style = "color:brown;">Null Hypothesis</span>
# 1. There is no significant relationship between Headcount Rate (%) and Severity of Poverty (%).
# 2. There is no significant relationship between Poverty Gap (%) and Severity of Poverty (%).
# 3. There is no significant relationship between Distribution of the Poor (%) and Severity of Poverty (%).
# ### <span style = "color:brown;">Alternative Hypothesis</span>
# 1. There is a significant relationship between Headcount Rate (%) and Severity of Poverty (%).
# 2. There is a significant relationship between Poverty Gap (%) and Severity of Poverty (%).
# 3. There is a significant relationship between Distribution of the Poor (%) and Severity of Poverty (%).
# ### <span style = "color:brown;">Relevance</span>
# By exploring the relationships between poverty indicators, such as headcount rate, poverty gap, and distribution of the poor, with the severity of poverty, we can gain insights into the key drivers of poverty in the country and inform policy and intervention strategies.
# ## <span style = "color:green;">Hypothesis Four</span>
# ### <span style = "color:brown;">Null Hypothesis</span>
# There is no significant difference between the proportion of households that accessed credit between
# those that sought credit and those that did not seek credit
# ### <span style = "color:brown;">Alternative Hypothesis</span>
# There is a significant difference between the proportion of households that accessed credit between
# those that sought credit and those that did not seek credit
# ### <span style = "color:brown;">Relevance</span>
# This hypothesis aims to investigate the factors that affect credit access among Kenyan households,
# with a focus on the impact of seeking credit. It is hypothesized that households that have sought
# credit before are more likely to access credit in the future.
# ## <span style = "color:green;">Hypothesis Five</span>
# ### <span style = "color:brown;">Null Hypothesis</span>
# The distribution of the poor is not correlated with credit access.
# ### <span style = "color:brown;">Alternative Hypothesis</span>
# The distribution of the poor is correlated with credit access.
# ### <span style = "color:brown;">Relevance</span>
# Poverty is distributed unevenly across different parts of Kenya. This hypothesis seeks to explore
# whether there is a relationship between the distribution of poverty and credit access in Kenya.

# %% [markdown]
# # <span style = "color:#1A237E;">Summary of observations and inferences</span>
# ### <span style = "color:green;">Hypothesis One</span>
# 1. The `mean proportion of households that sought and accessed credit` for counties with `Headcount
# Rate >= 50%` is `72.17%`, while the `mean proportion of households that sought and accessed credit`
# for counties with `Headcount Rate < 50%` is `89.50%`.
# 2. The correlation coefficient is `-0.4777`, which indicates _a moderate negative correlation between
# the `Headcount Rate (%)` and the `Proportion of households that sought credit (%)`_.
# 3. The `p-value` is `0.0379`, which is _below_ the commonly used threshold of `0.05`. This suggests
# that _the observed correlation between the two variables is statistically significant_, and not
# likely to have occurred by chance.
# 4. The `t-value` is `-2.368`, which indicates that _the means of the two groups are significantly
# different from each other_.
# 5. The `p-value` is `0.038`, which is `below the commonly used threshold` of `0.05`.
# This suggests that _the difference in means between the two groups is statistically significant_, and not
# likely to have occurred by chance.
# ### <span style = "color:green;">Hypothesis Two</span>
# 1. The Pearson correlation coefficient between the `Poverty Gap (%)` and `Proportion of households that
# sought credit (%)` is `-0.4777`, which means that there is a moderate negative correlation between
# these two variables. This indicates that as the `Poverty Gap (%)` increases, the `Proportion of
# households that sought credit (%)` _decreases_, and vice versa.
# 2. The `p-value` is `0.000684`, which is less than the commonly used threshold of `0.05`. This suggests
# that the observed correlation between the two variables _is statistically significant_, and not
# likely to have occurred by chance.
# ### <span style = "color:green;">Hypothesis Three</span>
# 1. **Severity_of_Poverty:** Has a _strong positive correlation_ with the `Headcount_Rate` and `Poverty_Gap`, and a _moderate positive correlation_ with the `Distribution_of_the_Poor` - important indicators.
# 2. **Poverty_Gap:** Has a _strong positive correlation_ with the `Headcount_Rate` and `Severity_of_Poverty`, and a moderate positive correlation with the `Distribution_of_the_Poor`.
# 3. **Distribution_of_the_Poor:** Has a moderate positive correlation with the `Severity_of_Poverty`, `Number of Poor (ths)`, and `Poverty_Gap` - may be a useful predictor.
#
# <br>The `R-squared` value of the model is `0.882`, which indicates that _`88.2%` of the variation in the dependent
# variable is explained by the independent variables in the model_.
# <br>The `adjusted R-squared` value of `0.874` also suggests that _the model is a good fit for the data_.
# <br>The `F-statistic` and its associated `p-value` indicate that _the model is statistically significant_.
# <br>`Poverty Gap (%)` has a `positive coefficient of 0.7962`, indicating that an _increase in poverty
# gap leads to an increase in severity of poverty_.
# <br>`Distribution of the Poor (%)` has a `negative coefficient of -0.1028`, indicating that _an
# increase in the proportion of the poor in more vulnerable sections of society leads to a decrease in the
# severity of poverty_ (interesting).
# <br>However, `Headcount Rate (%)` has a coefficient of only `0.0102`, which
# is `not statistically significant`, and therefore, we _cannot infer any significant relationship
# between headcount rate and severity of poverty_.
# <br>
# <br>
# The RMSE value of `1.7863860335702446` is **moderately high**, which suggests that _the model may not be
# suitable for accurately predicting the severity of poverty based on these independent variables
# alone_.
# <br>Therefore, it may be necessary to explore other variables that could be relevant to predicting
# poverty severity.
# ### <span style = "color:green;">Hypothesis Four</span>
# 1. The results of the **chi-square test** show that the `chi-square statistic` is `0.01275` and the `p-value` is `0.910`.
# 2. The `p-value` is greater than the typical significance level of `0.05`, indicating that there is not enough
# evidence to reject the null hypothesis.
# 3. A `t-statistic` of `infinity` and a `p-value` of `0` indicates a likelihood of very few observations
# in one of the groups, which can led to unstable estimates.
# <br>However, this can be interpreted as there being _there is a significant difference between the
# means of the two groups_ being compared.
# 4. The probability of accessing credit given that an individual sought credit is `9/(9+0) = 1`
# which means that all individuals who sought credit also accessed credit.
# 5. The probability of seeking credit given that an individual did not
# access credit is `0/(0+35) = 0`, which means that no individuals who did not access credit sought credit.
# ### <span style = "color:green;">Hypothesis Five</span>
# 1. A correlation coefficient of `0.005` indicates _a very weak positive correlation_ between the two
# variables, **while** the p-value of `0.972` suggests that _the correlation is not statistically significant_
# at the standard significance level of `0.05`.
# 2. This means that there is no evidence to suggest that the two variables are related to each other.
# Based on the contingency table and the conditional probabilities, there appears to be a relationship
# between seeking credit and accessing credit.
# 3. However, the results of the chi-square test are not consistent with this conclusion, likely due to the
# small sample size.

# %% [markdown]
# # <span style = "color:#1A237E;">Aggregate conclusions</span>
# 1. Household credit access in Kenya is negatively correlated with the headcount rate in a county.
# Households in counties with higher headcount rates are less likely to access credit.
# 2. Poverty gap is also negatively correlated with the proportion of households that sought credit in Kenya.
# Households in counties with higher poverty gaps are less likely to access credit.
# 3. The relationship between credit access and poverty levels in Kenya is inconclusive based on the available data.
# 4. There is no significant difference between the proportion of households that accessed credit between those that sought credit and those that did not seek credit.
# 5. The distribution of the poor is not significantly correlated with credit access in Kenya.
# 6. There is a positive relationship between poverty gap and severity of poverty.
# 7. The variation in the severity of poverty can be explained by the independent variables in the model.
# 8. An increase in the poverty gap leads to a higher severity of poverty.
# 9. An increase in the proportion of the poor in more vulnerable sections of society is associated
# with a decrease in the severity of poverty.
# 10. There is insufficient evidence to support a significant relationship between headcount rate and
# severity of poverty.

# %% [markdown]
# # <span style = "color:#1A237E;">Recommendations</span>
# ### <span style = "color:brown;">Increase credit access in areas with high poverty rates</span>
# Since households in counties with higher poverty rates are less likely to access credit, the government
# and NGOs should focus on increasing credit access in these areas. This can be done through initiatives
# such as microfinance programs, community-based credit schemes, and government-led credit programs.
#
# ### <span style = "color:brown;">Address the issue of poverty gap</span>
# Households in counties with higher poverty gaps are less likely to access credit. Additionally, there
# is a  positive relationship between poverty gap and severity of poverty.
# <br>Therefore, the government and NGOs should focus on reducing the poverty gap in these areas.
# This can be done through measures such as income redistribution, social safety nets, and
# targeted poverty alleviation programs.
#
# ### <span style = "color:brown;">Collect more data</span>
# The relationship between credit access and poverty levels in Kenya is inconclusive based on the
# available data. Therefore, the government and NGOs should collect more data on credit access and
# poverty levels to gain a better understanding of the relationship between the two.
#
# ### <span style = "color:brown;">Target vulnerable populations</span>
# The negative relationship between the distribution of the poor and severity of poverty suggests
# that efforts should be made to target and support vulnerable populations. This can be done
# through social welfare programs, skill development initiatives, and providing opportunities
# for income generation in marginalized communities.
